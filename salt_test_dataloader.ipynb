# %%
from dataset.dataset_stuff import SegmentationDataset, MaskDataset, SequentialDataset, TrainDataset, ValDataset, H5LikeFileInterface
import os
import cv2
from utils import get_config
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

print(os.getcwd())
# get config 
config = get_config('configs/default.json')
config
# Out:
# /home/rshvetsov/projects/proj_segmentation
# Config(dataset_path='data', models_dir='results', folder='lnma', img_rows=256, img_cols=256, target_rows=256, target_cols=256, num_channels=3, network='linknet34', loss='bce_dice_loss', lr=0.0001, optimizer='adam', batch_size=4, epoch_size=1, use_clahe=False, nb_epoch=40, cycle_start_epoch=23, predict_batch_size=5, use_crop=False, use_resize=True, dbg=False, save_images=True, test_pad=0, train_pad=0, fold=None, folds_num=5, split_name='area', iter_size=1)

# %%
root = config.dataset_path
image_folder_name = 'train/images'
ds = H5LikeFileInterface(SegmentationDataset(root,
                                             config.img_rows, config.img_cols,
                                             image_folder_name=image_folder_name,
                                             apply_clahe=config.use_clahe))

# %%
tr = TrainDataset(ds, np.arange(len(ds)), config, transform=None)

# %%
for elem in tr:
    img, mask = np.rollaxis(elem['image'], 0, 3), np.rollaxis(elem["mask"], 0, 3).squeeze()
    #print(img.shape, img.dtype, img.min(), img.max())
    #plt.figure()
    #plt.subplot(121); plt.imshow(img)
    #plt.subplot(122); plt.imshow(mask)
    #plt.show()
# Out:
# 0
# (256, 256, 3) float32 0.0 0.996078
# 1
# (256, 256, 3) float32 0.0 0.988235
# 2
# (256, 256, 3) float32 0.0352941 1.0
# 3
# (256, 256, 3) float32 0.0431373 0.937255
# 4
# (256, 256, 3) float32 0.00784314 0.937255
# 5
# (256, 256, 3) float32 0.00784314 0.984314
# 6
# (256, 256, 3) float32 0.00392157 1.0
# 7
# (256, 256, 3) float32 0.0 0.996078
# 8
# (256, 256, 3) float32 0.0 0.992157
# 9
# (256, 256, 3) float32 0.0 1.0
# 10
# (256, 256, 3) float32 0.00392157 0.996078
# 11
# (256, 256, 3) float32 0.00784314 0.964706
# 12
# (256, 256, 3) float32 0.00392157 1.0
# 13
# (256, 256, 3) float32 0.0156863 0.996078
# 14
# (256, 256, 3) float32 0.0235294 0.996078
# 15
# (256, 256, 3) float32 0.0196078 0.984314
# 16
# (256, 256, 3) float32 0.0 0.996078
# 17
# (256, 256, 3) float32 0.0196078 0.988235
# 18
# (256, 256, 3) float32 0.00392157 0.996078
# 19
# (256, 256, 3) float32 0.0196078 0.992157
# 20
# (256, 256, 3) float32 0.00392157 1.0
# 21
# (256, 256, 3) float32 0.00392157 1.0
# 22
# ...
